# %% [markdown]
# *Copyright 2024 Jaeyoung Chun*
#
# You may not make copies of this and use or distribute it for any purpose.

# %% [markdown]
# # Yellow Cards

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch

# %% [markdown]
# ## Load Data

# %%
df_events = pd.read_parquet("./data/raw_events.parquet")

# %%
df_events
# Out:
#      bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0                  None                 None                    None
# 1                  None                 None                    None
# 2                  None                 None                    None
# 3                  None                 None                    None
# 4                  None                 None                    None
# ...                 ...                  ...                     ...
# 3374               None                 None                    None
# 3375               None                 None                    None
# 3376               None                 None                    None
# 3377               None                 None                    None
# 3378        Yellow Card                 None                    None
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 0                              None             None               None
# 1                              None             None               None
# 2                              None             None               None
# 3                              None             None               None
# 4                              None             None               None
# ...                             ...              ...                ...
# 3374                           None             None               None
# 3375                           None             None               None
# 3376                           None             None               None
# 3377                           None             None               None
# 3378                           None             None               None
#
#      clearance_aerial_won clearance_body_part clearance_head  \
# 0                    None                None           None
# 1                    None                None           None
# 2                    None                None           None
# 3                    None                None           None
# 4                    None                None           None
# ...                   ...                 ...            ...
# 3374                 None                None           None
# 3375                 None                None           None
# 3376                 None                None           None
# 3377                 None                None           None
# 3378                 None                None           None
#
#      clearance_left_foot  ... shot_technique shot_type substitution_outcome  \
# 0                   None  ...           None      None                 None
# 1                   None  ...           None      None                 None
# 2                   None  ...           None      None                 None
# 3                   None  ...           None      None                 None
# 4                   None  ...           None      None                 None
# ...                  ...  ...            ...       ...                  ...
# 3374                None  ...           None      None             Tactical
# 3375                None  ...           None      None             Tactical
# 3376                None  ...           None      None             Tactical
# 3377                None  ...           None      None             Tactical
# 3378                None  ...           None      None                 None
#
#                      substitution_replacement  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
# ...                                       ...
# 3374                              Ui-Jo Hwang
# 3375                William Silva de Carvalho
# 3376  Bernardo Mota Veiga de Carvalho e Silva
# 3377                               Yu-Min Cho
# 3378                                     None
#
#                                                 tactics         team team_id  \
# 0     {'formation': 433.0, 'lineup': [{'jersey_numbe...  South Korea     791
# 1     {'formation': 433.0, 'lineup': [{'jersey_numbe...     Portugal     780
# 2                                                  None     Portugal     780
# 3                                                  None  South Korea     791
# 4                                                  None  South Korea     791
# ...                                                 ...          ...     ...
# 3374                                               None  South Korea     791
# 3375                                               None     Portugal     780
# 3376                                               None     Portugal     780
# 3377                                               None  South Korea     791
# 3378                                               None  South Korea     791
#
#          timestamp           type under_pressure
# 0     00:00:00.000    Starting XI           None
# 1     00:00:00.000    Starting XI           None
# 2     00:00:00.000     Half Start           None
# 3     00:00:00.000     Half Start           None
# 4     00:00:00.000     Half Start           None
# ...            ...            ...            ...
# 3374  00:36:13.753   Substitution           None
# 3375  00:36:13.762   Substitution           None
# 3376  00:36:13.790   Substitution           None
# 3377  00:47:46.061   Substitution           None
# 3378  00:47:36.651  Bad Behaviour           None
#
# [3379 rows x 88 columns]

# %% [markdown]
# ## Card Types

# %%
# columns that contain the word `card`
df_events.columns[ df_events.columns.str.contains("card") ]
# Out:
# Index(['bad_behaviour_card', 'foul_committed_card'], dtype='object')

# %% [markdown]
# ## Foul Committed

# %% [markdown]
# ### Search

# %%
df_yellow_cards = df_events[ df_events.foul_committed_card == "Yellow Card" ]

# %%
df_yellow_cards
# Out:
#      bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 3016               None                 None                    None
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 3016                           None             None               None
#
#      clearance_aerial_won clearance_body_part clearance_head  \
# 3016                 None                None           None
#
#      clearance_left_foot  ... shot_technique shot_type substitution_outcome  \
# 3016                None  ...           None      None                 None
#
#      substitution_replacement tactics         team team_id     timestamp  \
# 3016                     None    None  South Korea     791  00:35:42.240
#
#                 type under_pressure
# 3016  Foul Committed           None
#
# [1 rows x 88 columns]

# %% [markdown]
# ### Who, When, and Where?

# %%
df_yellow_cards.player
# Out:
# 3016    Kang-In Lee
# Name: player, dtype: object

# %%
df_yellow_cards.timestamp
# Out:
# 3016    00:35:42.240
# Name: timestamp, dtype: object

# %%
df_yellow_cards.location
# Out:
# 3016    [87.1, 37.6]
# Name: location, dtype: object

# %% [markdown]
# ### Visualization

# %%
pitch = Pitch(
    pitch_type="statsbomb",
    pitch_color="grass",
    line_color="white",
    stripe=True
)

fig, ax = pitch.draw()

df = df_yellow_cards.squeeze()
x, y = df.location

pitch.scatter(x, y, color="yellow", s=100, ax=ax)

pitch.annotate(
    df.player,
    (x - 10, y - 3),
    color="white", fontweight="bold",
    ax=ax
)

plt.show()

# %% [markdown]
# ## Bad Behaviour

# %% [markdown]
# ### Search

# %%
df_bad = df_events[ df_events.bad_behaviour_card == "Yellow Card"]

# %%
df_bad
# Out:
#      bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 3378        Yellow Card                 None                    None
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 3378                           None             None               None
#
#      clearance_aerial_won clearance_body_part clearance_head  \
# 3378                 None                None           None
#
#      clearance_left_foot  ... shot_technique shot_type substitution_outcome  \
# 3378                None  ...           None      None                 None
#
#      substitution_replacement tactics         team team_id     timestamp  \
# 3378                     None    None  South Korea     791  00:47:36.651
#
#                type under_pressure
# 3378  Bad Behaviour           None
#
# [1 rows x 88 columns]

# %% [markdown]
# ### Who, When, and Where?

# %%
df_bad.player
# Out:
# 3378    Hee-Chan Hwang
# Name: player, dtype: object

# %%
df_bad.timestamp
# Out:
# 3378    00:47:36.651
# Name: timestamp, dtype: object

# %%
df_bad.location
# Out:
# 3378    None
# Name: location, dtype: object

# %% [markdown]
# Why location is none?

# %% [markdown]
# ### Visualization

# %%
pitch = Pitch(
    pitch_type="statsbomb",
    pitch_color="grass",
    line_color="white",
    stripe=True
)

fig, ax = pitch.draw()

pitch.scatter(-2.2, 12, color="yellow", s=100, ax=ax)

pitch.annotate(
    df_bad.squeeze().player,
    (3, 13),
    color="white", fontweight="bold",
    ax=ax
)

plt.show()

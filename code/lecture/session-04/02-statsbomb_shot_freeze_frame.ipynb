# %% [markdown]
# *Copyright 2024 Jaeyoung Chun*
#
# You may not make copies of this and use or distribute it for any purpose.

# %% [markdown]
# # StatsBomb Shot Freeze Frame

# %%
from statsbombpy import sb
import warnings
#ignore by message
warnings.filterwarnings("ignore", message="credentials were not supplied")

import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch
from tqdm import tqdm

# %% [markdown]
# ## FIFA Worldcup 2022 Korea vs. Portugal

# %%
match_id = 3857262

# %%
df_events = sb.events(match_id=match_id)

# %% [markdown]
# ## Get Events

# %%
df_events
# Out:
#      bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0                   NaN                  NaN                     NaN
# 1                   NaN                  NaN                     NaN
# 2                   NaN                  NaN                     NaN
# 3                   NaN                  NaN                     NaN
# 4                   NaN                  NaN                     NaN
# ...                 ...                  ...                     ...
# 3374                NaN                  NaN                     NaN
# 3375                NaN                  NaN                     NaN
# 3376                NaN                  NaN                     NaN
# 3377                NaN                  NaN                     NaN
# 3378        Yellow Card                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 0                               NaN              NaN                NaN
# 1                               NaN              NaN                NaN
# 2                               NaN              NaN                NaN
# 3                               NaN              NaN                NaN
# 4                               NaN              NaN                NaN
# ...                             ...              ...                ...
# 3374                            NaN              NaN                NaN
# 3375                            NaN              NaN                NaN
# 3376                            NaN              NaN                NaN
# 3377                            NaN              NaN                NaN
# 3378                            NaN              NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  \
# 0                     NaN                 NaN            NaN
# 1                     NaN                 NaN            NaN
# 2                     NaN                 NaN            NaN
# 3                     NaN                 NaN            NaN
# 4                     NaN                 NaN            NaN
# ...                   ...                 ...            ...
# 3374                  NaN                 NaN            NaN
# 3375                  NaN                 NaN            NaN
# 3376                  NaN                 NaN            NaN
# 3377                  NaN                 NaN            NaN
# 3378                  NaN                 NaN            NaN
#
#      clearance_left_foot  ... shot_technique shot_type substitution_outcome  \
# 0                    NaN  ...            NaN       NaN                  NaN
# 1                    NaN  ...            NaN       NaN                  NaN
# 2                    NaN  ...            NaN       NaN                  NaN
# 3                    NaN  ...            NaN       NaN                  NaN
# 4                    NaN  ...            NaN       NaN                  NaN
# ...                  ...  ...            ...       ...                  ...
# 3374                 NaN  ...            NaN       NaN             Tactical
# 3375                 NaN  ...            NaN       NaN             Tactical
# 3376                 NaN  ...            NaN       NaN             Tactical
# 3377                 NaN  ...            NaN       NaN             Tactical
# 3378                 NaN  ...            NaN       NaN                  NaN
#
#                      substitution_replacement  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 3374                              Ui-Jo Hwang
# 3375                William Silva de Carvalho
# 3376  Bernardo Mota Veiga de Carvalho e Silva
# 3377                               Yu-Min Cho
# 3378                                      NaN
#
#                                                 tactics         team team_id  \
# 0     {'formation': 433, 'lineup': [{'player': {'id'...  South Korea     791
# 1     {'formation': 433, 'lineup': [{'player': {'id'...     Portugal     780
# 2                                                   NaN     Portugal     780
# 3                                                   NaN  South Korea     791
# 4                                                   NaN  South Korea     791
# ...                                                 ...          ...     ...
# 3374                                                NaN  South Korea     791
# 3375                                                NaN     Portugal     780
# 3376                                                NaN     Portugal     780
# 3377                                                NaN  South Korea     791
# 3378                                                NaN  South Korea     791
#
#          timestamp           type under_pressure
# 0     00:00:00.000    Starting XI            NaN
# 1     00:00:00.000    Starting XI            NaN
# 2     00:00:00.000     Half Start            NaN
# 3     00:00:00.000     Half Start            NaN
# 4     00:00:00.000     Half Start            NaN
# ...            ...            ...            ...
# 3374  00:36:13.753   Substitution            NaN
# 3375  00:36:13.762   Substitution            NaN
# 3376  00:36:13.790   Substitution            NaN
# 3377  00:47:46.061   Substitution            NaN
# 3378  00:47:36.651  Bad Behaviour            NaN
#
# [3379 rows x 88 columns]

# %% [markdown]
# ## Goal After 45 Mins

# %%
# convert to `timedelta` in order to make easy for time search
df_events.timestamp = pd.to_timedelta(df_events.timestamp)

# %%
# goal after 45 minutes
df_goals_45 = df_events[ (df_events.shot_outcome == "Goal") & (df_events.timestamp > "00:45:00") ]
df_goals_45
# Out:
#      bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 3230                NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# 3230                            NaN              NaN                NaN
#
#      clearance_aerial_won clearance_body_part clearance_head  \
# 3230                  NaN                 NaN            NaN
#
#      clearance_left_foot  ... shot_technique  shot_type substitution_outcome  \
# 3230                 NaN  ...         Normal  Open Play                  NaN
#
#      substitution_replacement tactics         team team_id  \
# 3230                      NaN     NaN  South Korea     791
#
#                   timestamp  type under_pressure
# 3230 0 days 00:45:28.560000  Shot            NaN
#
# [1 rows x 88 columns]

# %%
# get event index
event_idx = df_goals_45.index
event_idx
# Out:
# Index([3230], dtype='int64')

# %%
df_shot = df_events.loc[event_idx].squeeze()

# %%
# who shot?
df_shot.player
# Out:
# 'Hee-Chan Hwang'

# %% [markdown]
# ## Shot Freeze Frame

# %%
df_shot.shot_freeze_frame
# Out:
# [{'location': [93.0, 59.0],
#   'player': {'id': 40542, 'name': 'Gue-Sung Cho'},
#   'position': {'id': 22, 'name': 'Right Center Forward'},
#   'teammate': True},
#  {'location': [98.2, 52.9],
#   'player': {'id': 29966, 'name': 'Ui-Jo Hwang'},
#   'position': {'id': 24, 'name': 'Left Center Forward'},
#   'teammate': True},
#  {'location': [97.8, 51.2],
#   'player': {'id': 3083, 'name': 'Heung-Min Son'},
#   'position': {'id': 12, 'name': 'Right Midfield'},
#   'teammate': True},
#  {'location': [99.1, 51.1],
#   'player': {'id': 5214, 'name': 'William Silva de Carvalho'},
#   'position': {'id': 13, 'name': 'Right Center Midfield'},
#   'teammate': False},
#  {'location': [98.9, 48.6],
#   'player': {'id': 10868, 'name': 'Ricardo Jorge Luz Horta'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'teammate': False},
#  {'location': [101.1, 50.7],
#   'player': {'id': 16028, 'name': 'José Diogo Dalot Teixeira'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'teammate': False},
#  {'location': [102.8, 52.1],
#   'player': {'id': 7005, 'name': 'João Pedro Cavaco Cancelo'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'teammate': False},
#  {'location': [97.8, 38.9],
#   'player': {'id': 143854,
#    'name': 'António João Pereira Albuquerque Tavares Silva'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'teammate': False},
#  {'location': [102.5, 47.0],
#   'player': {'id': 12169, 'name': 'João Maria Lobo Alves Palhinha Gonçalves'},
#   'position': {'id': 10, 'name': 'Center Defensive Midfield'},
#   'teammate': False},
#  {'location': [102.7, 44.4],
#   'player': {'id': 20016, 'name': 'Kléper Laveran Lima Ferreira'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'teammate': False},
#  {'location': [107.1, 42.1],
#   'player': {'id': 3193, 'name': 'Bernardo Mota Veiga de Carvalho e Silva'},
#   'position': {'id': 15, 'name': 'Left Center Midfield'},
#   'teammate': False},
#  {'location': [115.2, 42.0],
#   'player': {'id': 32975, 'name': 'Diogo Meireles Costa'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'teammate': False}]

# %%
df_freeze = pd.DataFrame(df_shot.shot_freeze_frame)

# %%
df_freeze
# Out:
#          location                                             player  \
# 0    [93.0, 59.0]              {'id': 40542, 'name': 'Gue-Sung Cho'}
# 1    [98.2, 52.9]               {'id': 29966, 'name': 'Ui-Jo Hwang'}
# 2    [97.8, 51.2]              {'id': 3083, 'name': 'Heung-Min Son'}
# 3    [99.1, 51.1]  {'id': 5214, 'name': 'William Silva de Carvalho'}
# 4    [98.9, 48.6]   {'id': 10868, 'name': 'Ricardo Jorge Luz Horta'}
# 5   [101.1, 50.7]  {'id': 16028, 'name': 'José Diogo Dalot Teixei...
# 6   [102.8, 52.1]  {'id': 7005, 'name': 'João Pedro Cavaco Cancelo'}
# 7    [97.8, 38.9]  {'id': 143854, 'name': 'António João Pereira A...
# 8   [102.5, 47.0]  {'id': 12169, 'name': 'João Maria Lobo Alves P...
# 9   [102.7, 44.4]  {'id': 20016, 'name': 'Kléper Laveran Lima Fer...
# 10  [107.1, 42.1]  {'id': 3193, 'name': 'Bernardo Mota Veiga de C...
# 11  [115.2, 42.0]      {'id': 32975, 'name': 'Diogo Meireles Costa'}
#
#                                            position  teammate
# 0        {'id': 22, 'name': 'Right Center Forward'}      True
# 1         {'id': 24, 'name': 'Left Center Forward'}      True
# 2              {'id': 12, 'name': 'Right Midfield'}      True
# 3       {'id': 13, 'name': 'Right Center Midfield'}     False
# 4                  {'id': 17, 'name': 'Right Wing'}     False
# 5                   {'id': 2, 'name': 'Right Back'}     False
# 6                    {'id': 6, 'name': 'Left Back'}     False
# 7             {'id': 5, 'name': 'Left Center Back'}     False
# 8   {'id': 10, 'name': 'Center Defensive Midfield'}     False
# 9            {'id': 3, 'name': 'Right Center Back'}     False
# 10       {'id': 15, 'name': 'Left Center Midfield'}     False
# 11                  {'id': 1, 'name': 'Goalkeeper'}     False

# %% [markdown]
# ## Visualization

# %%
pitch = VerticalPitch(
    pitch_type="statsbomb",
    half=True
)

fig, ax = pitch.draw()

shot_x, shot_y = df_shot.location

pitch.scatter(
    shot_x, shot_y,
    marker="football",
    s=50, alpha=0.7, zorder=999,
    ax=ax
)

pitch.lines(
    shot_x, shot_y, 120, 36,
    color="red", linestyle="--", linewidth=1,
    ax=ax
)
pitch.lines(
    shot_x, shot_y, 120, 44,
    color="red", linestyle="--", linewidth=1,
    ax=ax
)

pitch.goal_angle(
    shot_x, shot_y, alpha=0.2, zorder=1.1,
    color='#cb5a4c', goal='right',
    ax=ax
)

for row in df_freeze.itertuples():

    player_x, player_y = row.location
    position = row.position

    if position["name"] == "Goalkeeper":
        pitch.scatter(
            player_x, player_y,
            c="black", s=20, alpha=0.7,
            ax=ax
        )
    else:
        pitch.scatter(
            player_x, player_y,
            c="silver" if row.teammate else "red", s=20, alpha=0.7,
            ax=ax
        )

    if row.teammate:
        player_name = row.player["name"]        
        pitch.annotate(player_name, (player_x, player_y - 15), ax=ax)

plt.show()
